# %%
import matplotlib.pyplot as plt

data1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
data2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.1, 6.13, 3.1, 9.13, 7.26, 4.74]
data3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]

# %%
plt.hist(data1)
# Out:
# (array([2., 0., 1., 0., 2., 2., 2., 0., 1., 1.]),
#  array([ 4.26 ,  4.918,  5.576,  6.234,  6.892,  7.55 ,  8.208,  8.866,
#          9.524, 10.182, 10.84 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data2)
# Out:
# (array([1., 0., 1., 0., 1., 0., 1., 0., 2., 5.]),
#  array([3.1  , 3.716, 4.332, 4.948, 5.564, 6.18 , 6.796, 7.412, 8.028,
#         8.644, 9.26 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data3)
# Out:
# (array([3., 2., 2., 2., 1., 0., 0., 0., 0., 1.]),
#  array([ 5.39 ,  6.125,  6.86 ,  7.595,  8.33 ,  9.065,  9.8  , 10.535,
#         11.27 , 12.005, 12.74 ]),
#  <BarContainer object of 10 artists>)
